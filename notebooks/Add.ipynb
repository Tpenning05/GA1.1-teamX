# %%
def add(a, b):
    return a + b 

print(add(4,3))
print(add(9384, 343))
# Out:
# 7
# 9727

# %%
def sum_list(values):
    total = 0
    for i in range(len(values)):
        total = add(total, values[i])
    return total

sum_list([1, 2, 3, 4, 5])
# Out:
# 15
